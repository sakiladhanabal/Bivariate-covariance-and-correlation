# %%
import pandas as pd

# %%
dataset=pd.read_csv("preplacementdata.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
dataset.cov(numeric_only=True)
# Out:
#                   sl_no         ssc_p         hsc_p     degree_p  \
# sl_no       3870.000000    -52.641355    -58.106028   -40.413645
# ssc_p        -52.641355    117.228377     60.348373    42.897137
# hsc_p        -58.106028     60.348373    118.755706    34.819820
# degree_p     -40.413645     42.897137     34.819820    54.151103
# etest_p       52.556168     37.659225     35.461678    21.929469
# mba_p          8.102336     24.535952     22.555846    17.272020
# salary    248400.921950  19767.643976  46008.057275 -8064.357161
#
#                 etest_p         mba_p        salary
# sl_no         52.556168      8.102336  2.484009e+05
# ssc_p         37.659225     24.535952  1.976764e+04
# hsc_p         35.461678     22.555846  4.600806e+04
# degree_p      21.929469     17.272020 -8.064357e+03
# etest_p      176.251018     16.886973  1.571579e+05
# mba_p         16.886973     34.028376  6.611551e+04
# salary    157157.850783  66115.509283  5.999726e+09

# %%
#In this above covariance table now we can find the covariance between the etest_p and mba_p mark.
#The value of this covariance is 16.88 .it is in positive value so that the covariance is positive covariance
#difference is 16 (the variance is very small)

#Next we need to find the covariance between degree_p and etest_p the covariance value is 21.92 this is also a positive 
#covariance difference is 21.92(the variance is small value)

# %%
dataset.corr(numeric_only=True)
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.051550
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.023571
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.054506
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364 -0.014148
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.152829
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.146324
# salary    0.051550  0.023571  0.054506 -0.014148  0.152829  0.146324  1.000000

# %%
#We need to find the correlation between the mba_p and  salary  it is directly propostional only 14%.
#if mba_p mark get increased salary also get increased 
#but the increament ratio is only 14%
